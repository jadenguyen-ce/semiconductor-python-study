# %%
import pandas as pd

manual = pd.DataFrame({'Sample_id': [1, 2], 'cd_nm': [14.2, 13.8], 'thickness_nm': [44.8, 45.1], 'operator': ['op_A', 'op_B'], 'pass_fail': ['pass', 'pass']})

#print (manual)

manual = pd.read_csv ("C:/Users/loanp/OneDrive/Desktop/JADE/ENGR_6MPLAN/python/week 1/fake_metrology.csv.txt")

print (manual)
# Out:
#    sample_id  cd_nm  thickness_nm    operator pass_fail
# 0          1   14.2          44.8  operator_A      pass
# 1          2   13.8          45.1  operator_B      pass
# 2          3   14.5          44.2  operator_A      pass
# 3          4   15.1          46.3  operator_B      fail
# 4          5   13.5          43.9  operator_A      pass
# 5          6   14.0          45.0  operator_C      pass
# 6          7   14.8          45.8  operator_B      pass
# 7          8   13.2          43.1  operator_C      fail
# 8          9   14.1          44.9  operator_A      pass
# 9         10   14.6          45.5  operator_B      pass
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       7 manual = pd.read_csv ("C:/Users/loanp/OneDrive/Desktop/JADE/ENGR_6MPLAN/python/week 1/fake_metrology.csv.txt")
#       9 print (manual)
# ---> 10 manual.shape()
#
# ...

# %%
manual.head()
# Out:
#    sample_id  cd_nm  thickness_nm    operator pass_fail
# 0          1   14.2          44.8  operator_A      pass
# 1          2   13.8          45.1  operator_B      pass
# 2          3   14.5          44.2  operator_A      pass
# 3          4   15.1          46.3  operator_B      fail
# 4          5   13.5          43.9  operator_A      pass

# %%
import pandas as pd

# Load your metrology data
df = pd.read_csv("C:/Users/loanp/OneDrive/Desktop/JADE/ENGR_6MPLAN/python/week 1/fake_metrology.csv.txt")
# Explore it
# print(df.shape)
# print(df.head())
# print(df.dtypes)
print(df.describe())
# Out:
#        sample_id      cd_nm  thickness_nm
# count   10.00000  10.000000     10.000000
# mean     5.50000  14.180000     44.860000
# std      3.02765   0.588407      0.937135
# min      1.00000  13.200000     43.100000
# 25%      3.25000  13.850000     44.350000
# 50%      5.50000  14.150000     44.950000
# 75%      7.75000  14.575000     45.400000
# max     10.00000  15.100000     46.300000
