# %%
import pandas as pd

tool_log = pd.read_csv("C:/Users/loanp/OneDrive/Desktop/JADE/ENGR_6MPLAN/python/week_2/tool_log.csv")
print (tool_log)

# %%
# # Check for missing values
# print(tool_log.isnull().sum())
# # Check what percentage of each column is missing
# print(tool_log.isnull().mean()*100)

# Fill missing values with the column mean
tool_log["notes"] = tool_log["notes"].fillna(tool_log["notes"])

# Convert a column to a different data type if needed
tool_log["frequency"] = tool_log["frequency"].astype("int")

print(tool_log.dtypes)
# Out:
# tool_id               object
# tool_name             object
# tool_type             object
# manufacturer          object
# date_logged           object
# issue_category        object
# issue_description     object
# severity              object
# frequency              int64
# downtime_hours       float64
# root_cause            object
# resolution            object
# resolved_date         object
# sample_type           object
# logged_by             object
# notes                 object
# dtype: object
