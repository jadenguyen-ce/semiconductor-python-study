# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("C:/Users/loanp/OneDrive/Desktop/JADE/ENGR_6MPLAN/python/week 1/fake_metrology.csv.txt")

# Explore it
# print(df.shape)
# print(df)
# print(df.dtypes)
# print(df.describe)
# fail_samples = df.loc[df.pass_fail == 'fail'] 
# print(fail_samples)
# df.set_index('sample_id')
# df.loc[df.operator == 'operator_A']
# df.loc[df.operator.isin (['operator_A', 'operator_C'])]
df.loc[(df.operator == 'operator_B') & (df.pass_fail == 'fail')]
# Out:
#    sample_id  cd_nm  thickness_nm    operator pass_fail
# 3          4   15.1          46.3  operator_B      fail
